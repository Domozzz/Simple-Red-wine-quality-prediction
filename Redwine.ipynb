# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn import tree
#if use decision tree as a model training tree.DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
# loading the csv data to a Pandas DataFrame
Redwine_data = pd.read_csv('./RedWine-Dataset/Redwine.csv')

# %%
# statistical measures about the data
Redwine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# plot correlation matrix
corr = Redwine_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col0,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col1,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col2,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col3,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col4,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row5_col5,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row6_col6,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row7_col7,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row8_col8,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row9_col9,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row10_col10,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col1,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col11,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row9_col1{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col2{
#             background-color:  #f08a6c;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col3,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col10{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col4{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col5,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col8,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col2,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col9,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col11,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col1,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row7_col10,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row8_col0,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row8_col3,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row8_col4,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row10_col6,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row10_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col6{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col7{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col9,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col8{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col10,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col11{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row0_col11,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col4,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row7_col1,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row7_col4,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row10_col0{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col0,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col4,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row5_col3{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col3,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col5{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col4{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col5{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col6{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col7{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col8{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row1_col10{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col0{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col3,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col9,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row5_col4,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row11_col7{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col6,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row7_col8{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col7{
#             background-color:  #eed0c0;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col8,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row9_col3{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col9{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col10,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row6_col1,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row7_col3{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row2_col11{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col0{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col1{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col2,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row5_col8{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col5{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col6,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row6_col0{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col7{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row3_col10{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col0,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row9_col11{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col1{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col2{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col3{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col5{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col6{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col7{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col8,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row5_col9,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row6_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row4_col9,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row9_col4,#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row11_col2{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_aa3b5d8a_6323_11ec_9577_04d4c47165d9row5_col0{
#             background-color:  #a3c2fe;

# %% [markdown]
# Splitting the Features and Target

# %%
X = Redwine_data.drop(columns='quality', axis=1)
Y = Redwine_data['quality']

# %%
print(X)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
print(Y)
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# Splitting the Data into Training data & Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=42,stratify=Y)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1599, 11) (1279, 11) (320, 11)

# %% [markdown]
# Model Training

# %%
model = RandomForestClassifier()

# %%
# training the model with Training data
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
# accuracy_score on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy*100)
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy*100)
# Out:
# Accuracy on Training data :  100.0
# Accuracy on Test data :  66.875

# %%
# precision_score on training data
X_train_prediction = model.predict(X_train)
training_data_precision = precision_score(X_train_prediction, Y_train, average='weighted')
print('Precision on Training data : ', training_data_precision*100)
# precision on test data
X_test_prediction = model.predict(X_test)
test_data_precision = precision_score(X_test_prediction, Y_test, average='weighted')
print('Precision on Test data : ', test_data_precision*100)
# Out:
# Precision on Training data :  100.0
# Precision on Test data :  70.86018880208333

# %%
# recall_score on training data
X_train_prediction = model.predict(X_train)
training_data_recall = recall_score(X_train_prediction, Y_train, average='weighted')
print('Recall on Training data : ', training_data_recall*100)
# recall_score on test data
X_test_prediction = model.predict(X_test)
test_data_recall = recall_score(X_test_prediction, Y_test, average='weighted')
print('Recall on Test data : ', test_data_recall*100)
# Out:
# Recall on Training data :  100.0
# Recall on Test data :  66.875
# C:\Users\chatt\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#  f1_score  on training data
X_train_prediction = model.predict(X_train)
training_data_f1 = f1_score(X_train_prediction, Y_train, average='macro')
print('F1 on Training data : ', training_data_f1*100)
#  f1_score  on test data
X_test_prediction = model.predict(X_test)
test_data_f1 = f1_score(X_test_prediction, Y_test, average='macro')
print('F1 on Test data : ', test_data_f1*100)
# Out:
# F1 on Training data :  100.0
# F1 on Test data :  39.78476412264916

# %% [markdown]
# Predictive System

# %%
input_data = (7.3,0.65,0,1.2,0.065,15,21,0.9946,3.39,0.47,10)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print("Red wine quality is :",prediction)
if prediction  >=6:
    print("The wine is good quality")
else:
    print("The wine is bad quality")
# Out:
# Red wine quality is : [7]
# The wine is good quality
